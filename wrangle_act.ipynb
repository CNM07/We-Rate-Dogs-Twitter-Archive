# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# ## Table of Contents
#
# 1. [Data Gathering](#DataGathering)
# 2. [Assessing Data](#AssessingData)
# 3. [Cleaning Data](#CleaningData)
# 4. [Storing Data](#StoringData)
# 5. [Analyzing and Visualizing Data](#AnalyzingandVisualizingData)

# %% [markdown]
# ## Data Gathering
# <a id="DataGathering"></a>
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
import pandas as pd 
import numpy as np
import requests
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
import json

# %%
df1 = pd.read_csv('twitter-archive-enhanced.csv')

# %%
df1.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
import requests
url = ' https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

# %%
with open('image_predictions.tsv', mode ='wb') as file:
    file.write(response.content)

# %%
df2 = pd.read_csv('image_predictions.tsv', sep='\t' )

# %%
df2.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
tweets_list = []
with open('tweet-json.txt', 'r') as file:
    for line in file:
        tweets = json.loads(line)
        tweet_id = tweets['id']
        retweet_count = tweets['retweet_count']
        favorite_count = tweets['favorite_count']
        
        tweets_list.append({'tweet_id': int(tweet_id),
                            'retweet_count': int(retweet_count),
                            'favorite_count': int(favorite_count)
                            })

# %%
# Create DataFrames from list of dictionaries
df3 = pd.DataFrame(tweets_list, columns = ['tweet_id', 'retweet_count', 'favorite_count'])

# Save the dataFrame in file
df3.to_csv('tweet_json.txt', encoding = 'utf-8', index=False)

# %%
df3.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %% [markdown]
# ## Assessing Data
# <a id="AssessingData"></a>
#
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment
# programmatic assessement to assess the data.
#
# **Note:** pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %% [markdown]
# #### Assessing the First Dataset - twitter_archive_enhanced.csv (df1)

# %%
df1.T
# Out:
#                                                                          0     \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# ...

# %%
df1.shape
# Out:
# (2356, 17)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
df1.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
df1.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 915   757354760399941633                    NaN                  NaN
# 147   863432100342583297                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 426   821407182352777218                    NaN                  NaN
# 1711  680497766108381184                    NaN                  NaN
#
#                       timestamp  \
# 915   2016-07-24 23:20:20 +0000
# 147   2017-05-13 16:33:49 +0000
# 2353  2015-11-15 23:21:54 +0000
# 426   2017-01-17 17:21:47 +0000
# 1711  2015-12-25 21:18:05 +0000
#
#                                                  source  \
# 915   <a href="http://twitter.com/download/iphone" r...
# 147   <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 426   <a href="http://twitter.com/download/iphone" r...
# 1711  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df1.tweet_id.duplicated().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
df1['name'].value_counts()
# Out:
# None          745
# a              55
# Charlie        12
# Lucy           11
# Oliver         11
# Cooper         11
# Tucker         10
# Lola           10
# Penny          10
# Winston         9
# Bo              9
# Sadie           8
# the             8
# Toby            7
# an              7
# Daisy           7
# Buddy           7
# Bailey          7
# Rusty           6
# Jax             6
# Koda            6
# Stanley         6
# Scout           6
# Jack            6
# Milo            6
# Leo             6
# Dave            6
# Oscar           6
# Bella           6
# very            5
#              ...
# Mack            1
# Storkson        1
# Wafer           1
# Ace             1
# Lacy            1
# Dunkin          1
# Brudge          1
# Angel           1
# Clarkus         1
# Baron           1
# Wishes          1
# Cedrick         1
# Rhino           1
# Murphy          1
# Vixen           1
# Dutch           1
# Gustav          1
# DayZ            1
# Emmie           1
# ...

# %%
df1[df1.name=='a']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 56    881536004380872706                    NaN                  NaN
# 649   792913359805018113                    NaN                  NaN
# 801   772581559778025472                    NaN                  NaN
# 1002  747885874273214464                    NaN                  NaN
# 1004  747816857231626240                    NaN                  NaN
# 1017  746872823977771008                    NaN                  NaN
# 1049  743222593470234624                    NaN                  NaN
# 1193  717537687239008257                    NaN                  NaN
# 1207  715733265223708672                    NaN                  NaN
# 1340  704859558691414016                    NaN                  NaN
# 1351  704054845121142784                    NaN                  NaN
# 1361  703079050210877440                    NaN                  NaN
# 1368  702539513671897089                    NaN                  NaN
# ...

# %%
df1[df1.name=='an']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 759   778396591732486144                    NaN                  NaN
# 1025  746369468511756288                    NaN                  NaN
# 1362  703041949650034688                    NaN                  NaN
# 2204  668636665813057536                    NaN                  NaN
# 2333  666337882303524864                    NaN                  NaN
# 2335  666287406224695296                    NaN                  NaN
# 2349  666051853826850816                    NaN                  NaN
#
#                       timestamp  \
# 759   2016-09-21 00:53:04 +0000
# 1025  2016-06-24 15:48:42 +0000
# 1362  2016-02-26 02:20:37 +0000
# 2204  2015-11-23 03:46:18 +0000
# 2333  2015-11-16 19:31:45 +0000
# 2335  2015-11-16 16:11:11 +0000
# 2349  2015-11-16 00:35:11 +0000
#
#                                                  source  \
# 759   <a href="http://twitter.com/download/iphone" r...
# ...

# %%
df1[df1.name=='the']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1527  690360449368465409                    NaN                  NaN
# 1603  685943807276412928                    NaN                  NaN
# 1797  677269281705472000                    NaN                  NaN
# 1815  676613908052996102                    NaN                  NaN
# 2037  671561002136281088                    NaN                  NaN
# 2212  668587383441514497                    NaN                  NaN
# 2345  666063827256086533                    NaN                  NaN
# 2346  666058600524156928                    NaN                  NaN
#
#                       timestamp  \
# 1527  2016-01-22 02:28:52 +0000
# 1603  2016-01-09 21:58:42 +0000
# 1797  2015-12-16 23:29:14 +0000
# 1815  2015-12-15 04:05:01 +0000
# 2037  2015-12-01 05:26:34 +0000
# 2212  2015-11-23 00:30:28 +0000
# 2345  2015-11-16 01:22:45 +0000
# 2346  2015-11-16 01:01:59 +0000
#
# ...

# %%
df1[df1.name=='None']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 5     891087950875897856                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 24    887343217045368832                    NaN                  NaN
# 25    887101392804085760                    NaN                  NaN
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 32    886054160059072513                    NaN                  NaN
# 35    885518971528720385                    NaN                  NaN
# 37    885167619883638784                    NaN                  NaN
# 41    884441805382717440                    NaN                  NaN
# 42    884247878851493888                    NaN                  NaN
# 47    883117836046086144                    NaN                  NaN
# 55    881633300179243008           8.816070e+17         4.738443e+07
# ...

# %%
df1.name.str.islower().sum()
#tw_archive_df['name'].str.islower().sum()
# Out:
# 109

# %%
df1.retweeted_status_id.count()
# Out:
# 181

# %% [markdown]
# #### Assessing the Second Dataset - image_predictions.tsv (df2)

# %%
df2.head(25)
# Out:
#               tweet_id                                          jpg_url  \
# 0   666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1   666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2   666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3   666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4   666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5   666050758794694657  https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6   666051853826850816  https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7   666055525042405380  https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8   666057090499244032  https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9   666058600524156928  https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10  666063827256086533  https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# 11  666071193221509120  https://pbs.twimg.com/media/CT5cN_3WEAAlOoZ.jpg
# ...

# %%
df2.shape
# Out:
# (2075, 12)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df2.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
df2.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 1439  774639387460112384  https://pbs.twimg.com/media/CsASZqRW8AA3Szw.jpg
# 1666  812709060537683968  https://pbs.twimg.com/media/C0dSk98WEAALyya.jpg
# 753   688179443353796608  https://pbs.twimg.com/media/CYznjAcUEAQ5Zq7.jpg
# 780   689977555533848577  https://pbs.twimg.com/media/CZNK7NpWwAEAqUh.jpg
# 1537  790698755171364864  https://pbs.twimg.com/media/CvkgUjbUsAEvo7l.jpg
#
#       img_num                    p1   p1_conf  p1_dog                  p2  \
# 1439        1          Walker_hound  0.627593    True             basenji
# 1666        1          Irish_setter  0.326873    True    golden_retriever
# 753         1                sorrel  0.811520   False          horse_cart
# 780         1            cowboy_hat  0.291081   False  Labrador_retriever
# 1537        1  Bernese_mountain_dog  0.996541    True         EntleBucher
#
#        p2_conf  p2_dog             p3   p3_conf  p3_dog
# ...

# %%
df2.tweet_id.duplicated().sum()
# Out:
# 0

# %%
df2.isnull().sum()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %%
df2.p1.value_counts()
# Out:
# golden_retriever             150
# Labrador_retriever           100
# Pembroke                      89
# Chihuahua                     83
# pug                           57
# chow                          44
# Samoyed                       43
# toy_poodle                    39
# Pomeranian                    38
# cocker_spaniel                30
# malamute                      30
# French_bulldog                26
# Chesapeake_Bay_retriever      23
# miniature_pinscher            23
# seat_belt                     22
# Staffordshire_bullterrier     20
# German_shepherd               20
# Siberian_husky                20
# Cardigan                      19
# web_site                      19
# Maltese_dog                   18
# teddy                         18
# Shetland_sheepdog             18
# beagle                        18
# Eskimo_dog                    18
# Shih-Tzu                      17
# Lakeland_terrier              17
# Rottweiler                    17
# ...

# %%
df2['jpg_url'].value_counts()
# Out:
# https://pbs.twimg.com/media/Cbs3DOAXIAAp3Bd.jpg                                            2
# https://pbs.twimg.com/media/CtKHLuCWYAA2TTs.jpg                                            2
# https://pbs.twimg.com/media/Cp6db4-XYAAMmqL.jpg                                            2
# https://pbs.twimg.com/media/C12x-JTVIAAzdfl.jpg                                            2
# https://pbs.twimg.com/media/CwiuEJmW8AAZnit.jpg                                            2
# https://pbs.twimg.com/media/Co-hmcYXYAASkiG.jpg                                            2
# https://pbs.twimg.com/media/CeRoBaxWEAABi0X.jpg                                            2
# https://pbs.twimg.com/media/CcG07BYW0AErrC9.jpg                                            2
# https://pbs.twimg.com/media/Cq9guJ5WgAADfpF.jpg                                            2
# https://pbs.twimg.com/media/DA7iHL5U0AA1OQo.jpg                                            2
# ...

# %%
df2[df2['jpg_url'] == 'https://pbs.twimg.com/media/CZhn-QAWwAASQan.jpg']
# Out:
#                 tweet_id                                          jpg_url  \
# 800   691416866452082688  https://pbs.twimg.com/media/CZhn-QAWwAASQan.jpg
# 1624  803692223237865472  https://pbs.twimg.com/media/CZhn-QAWwAASQan.jpg
#
#       img_num                p1   p1_conf  p1_dog             p2   p2_conf  \
# 800         1  Lakeland_terrier  0.530104    True  Irish_terrier  0.197314
# 1624        1  Lakeland_terrier  0.530104    True  Irish_terrier  0.197314
#
#       p2_dog        p3   p3_conf  p3_dog
# 800     True  Airedale  0.082515    True
# 1624    True  Airedale  0.082515    True

# %%
df2.jpg_url.duplicated().sum()
# Out:
# 66

# %% [markdown]
# #### Assessing the Third Dataset - tweet_json.txt (df3)

# %%
df3.head(25)
# Out:
#               tweet_id  retweet_count  favorite_count
# 0   892420643555336193           8853           39467
# 1   892177421306343426           6514           33819
# 2   891815181378084864           4328           25461
# 3   891689557279858688           8964           42908
# 4   891327558926688256           9774           41048
# 5   891087950875897856           3261           20562
# 6   890971913173991426           2158           12041
# 7   890729181411237888          16716           56848
# 8   890609185150312448           4429           28226
# 9   890240255349198849           7711           32467
# 10  890006608113172480           7624           31166
# 11  889880896479866881           5156           28268
# 12  889665388333682689           8538           38818
# 13  889638837579907072           4735           27672
# 14  889531135344209921           2321           15359
# 15  889278841981685760           5637           25652
# ...

# %%
df3.shape
# Out:
# (2354, 3)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2354 non-null int64
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.2 KB

# %%
df3.describe()
# Out:
#            tweet_id  retweet_count  favorite_count
# count  2.354000e+03    2354.000000     2354.000000
# mean   7.426978e+17    3164.797366     8080.968564
# std    6.852812e+16    5284.770364    11814.771334
# min    6.660209e+17       0.000000        0.000000
# 25%    6.783975e+17     624.500000     1415.000000
# 50%    7.194596e+17    1473.500000     3603.500000
# 75%    7.993058e+17    3652.000000    10122.250000
# max    8.924206e+17   79515.000000   132810.000000

# %%
df3.sample(5)
# Out:
#                 tweet_id  retweet_count  favorite_count
# 261   842765311967449089           1439            7321
# 1087  737800304142471168           3904           10943
# 1357  703356393781329922            429            2085
# 1128  729113531270991872            370            2054
# 845   766078092750233600           2970               0

# %%
df3.tweet_id.duplicated().sum()
# Out:
# 0

# %%
df3.isnull().sum()
# Out:
# tweet_id          0
# retweet_count     0
# favorite_count    0
# dtype: int64

# %%
df3[df3.tweet_id == 666020888022790149]
# Out:
#                 tweet_id  retweet_count  favorite_count
# 2353  666020888022790149            532            2535

# %%
all_columns = pd.Series(list(df1) + list(df2) + list(df3))
all_columns[all_columns.duplicated()]
# Out:
# 17    tweet_id
# 29    tweet_id
# dtype: object

# %% [markdown]
# ### Quality issues
# 1. df1 - timestamp is string instead of datetime ✓
#
#
# 2. df1 - inconsistency in dog name column, some start with uppercase, some with lowercase  ✓
#
#
# 3. df1 - Some of the data contains retweets and replies ✓
#
#
# 4. df1 - 0 as a denominator (and other denominators which are not 10) ✓
#
#
# 5. df1 - name column has invalid names e.g. 'a', 'an', 'the' ✓
#
#
# 6. df1 - 'None' instead of NaN for missing values ✓
#
#
# 7. df2 - tweet_ids with the same jpg_url, duplicates
#
#
# 8. df2 - prediction dog breeds inconsistent, have both uppercase and lowercase for the first letter ✓
#
#
# 9. general - tweet_id for all tables is int, should be string ✓
#
#
# 10. general - unnecessary columns not for use in the analysis

# %% [markdown]
# ### Tidiness issues
# 1. df1 - Stages of dog ages are in columns instead of one row ✓
#
#
# 2. general - 3 different tables, all with tweet_id column

# %% [markdown]
# ## Cleaning Data
# <a id="CleaningData"></a>
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Copy of df1
df1_clean = df1.copy()

# %%
# Copy of df2
df2_clean = df2.copy()

# %%
# Copy of df1
df3_clean = df3.copy()

# %% [markdown]
# ### Issue #1: Change type for timestamp column (df1)

# %% [markdown]
# #### Define
# 1. Change timestamp column type from string to datetime

# %% [markdown]
# #### Code

# %%
df1_clean.timestamp = pd.to_datetime(df1_clean.timestamp)

# %% [markdown]
# #### Test

# %%
df1_clean.dtypes
# Out:
# tweet_id                               int64
# in_reply_to_status_id                float64
# in_reply_to_user_id                  float64
# timestamp                     datetime64[ns]
# source                                object
# text                                  object
# retweeted_status_id                  float64
# retweeted_status_user_id             float64
# retweeted_status_timestamp            object
# expanded_urls                         object
# rating_numerator                       int64
# rating_denominator                     int64
# name                                  object
# doggo                                 object
# floofer                               object
# pupper                                object
# puppo                                 object
# dtype: object

# %% [markdown]
# ### Issue #2: Use only original tweets/ratings that have images (df1)
# We only want to use original tweets with images, not retweets or replies.

# %% [markdown]
# #### Define:
# 1. Remove rows which are replies or retweets
# 2. Drop columns associated with replies and retweets

# %% [markdown]
# #### Code

# %%
# They do not have NaNs in 'retweeted_status_id'
rts = (~df1_clean.retweeted_status_id.isnull())

# And remove them from df_arch_clean
df1_clean = df1_clean[~rts]

# %%
# They do not have NaNs in 'in_reply_to_status_id'
replies = (~df1_clean.in_reply_to_status_id.isnull())

# And remove them from df_arch_clean
df1_clean = df1_clean[~replies]

# %%
# Remove not needed columns
df1_clean.drop(['in_reply_to_status_id', 
                    'in_reply_to_user_id', 
                    'retweeted_status_id', 
                    'retweeted_status_user_id', 
                    'retweeted_status_timestamp'], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
df1_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2097 non-null int64
# timestamp             2097 non-null datetime64[ns]
# source                2097 non-null object
# text                  2097 non-null object
# expanded_urls         2094 non-null object
# rating_numerator      2097 non-null int64
# rating_denominator    2097 non-null int64
# name                  2097 non-null object
# doggo                 2097 non-null object
# floofer               2097 non-null object
# pupper                2097 non-null object
# puppo                 2097 non-null object
# dtypes: datetime64[ns](1), int64(3), object(8)
# memory usage: 213.0+ KB

# %% [markdown]
# ### Issue #3: Capitalize names of dogs (df1)

# %% [markdown]
# #### Define
# 1. Capitalize first letter of dog names to have a uniform column

# %% [markdown]
# #### Code

# %%
df1_clean['name'] = [name.capitalize() for name in df1_clean['name']]

# %% [markdown]
# #### Test

# %%
df1_clean['name'].head(15)
# Out:
# 0      Phineas
# 1        Tilly
# 2       Archie
# 3        Darla
# 4     Franklin
# 5         None
# 6          Jax
# 7         None
# 8         Zoey
# 9       Cassie
# 10        Koda
# 11       Bruno
# 12        None
# 13         Ted
# 14      Stuart
# Name: name, dtype: object

# %%
df1_clean['name'].sample(15)
# Out:
# 1830    Kenneth
# 533       Ollie
# 2215       None
# 517      Hunter
# 31      Waffles
# 1226       Kanu
# 326     Charlie
# 819        Very
# 1053       None
# 232     Georgie
# 14       Stuart
# 883        Fido
# 1966       None
# 1299       None
# 979     Atticus
# Name: name, dtype: object

# %% [markdown]
# ### Issue #4:  Having all denominators in the dataset as 10 (df1)

# %% [markdown]
# #### Define
# 1. Change denominators to 10 of any obsrvations that has a denominator that is not 10.

# %% [markdown]
# #### Code

# %%
sum(df1_clean.rating_denominator!=10)
# Out:
# 17

# %%
for i in df1_clean.rating_denominator:
    df1_clean.rating_denominator=10
    
#df1_clean=df1_clean[df1_clean.rating_denominator ==10]

# %% [markdown]
# #### Test

# %%
sum(df1_clean.rating_denominator!=10)
# Out:
# 0

# %%
df1_clean.rating_denominator.describe()
# Out:
# count    2097.0
# mean       10.0
# std         0.0
# min        10.0
# 25%        10.0
# 50%        10.0
# 75%        10.0
# max        10.0
# Name: rating_denominator, dtype: float64

# %% [markdown]
# ### Issue #5: 'None' instead of NaN for missing values (df1)

# %% [markdown]
# #### Define
# 1. Change out the word 'None' for numpy NaN where there are missing values.

# %% [markdown]
# #### Code

# %%
df1_clean['name'] = df1_clean['name'].replace('None', np.nan)
#df.replace(to_replace=[None], value=np.nan, inplace=True)
df1_clean['doggo'] = df1_clean['doggo'].replace('None', np.nan)
df1_clean['floofer'] = df1_clean['floofer'].replace('None', np.nan)
df1_clean['pupper'] = df1_clean['pupper'].replace('None', np.nan)
df1_clean['puppo'] = df1_clean['puppo'].replace('None', np.nan)

# %% [markdown]
# #### Test

# %%
df1_clean.head(10)
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
# 1  892177421306343426 2017-08-01 00:17:27
# 2  891815181378084864 2017-07-31 00:18:03
# 3  891689557279858688 2017-07-30 15:58:51
# 4  891327558926688256 2017-07-29 16:00:24
# 5  891087950875897856 2017-07-29 00:08:17
# 6  890971913173991426 2017-07-28 16:27:12
# 7  890729181411237888 2017-07-28 00:22:40
# 8  890609185150312448 2017-07-27 16:25:51
# 9  890240255349198849 2017-07-26 15:59:51
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
# 5  <a href="http://twitter.com/download/iphone" r...
# 6  <a href="http://twitter.com/download/iphone" r...
# 7  <a href="http://twitter.com/download/iphone" r...
# ...

# %% [markdown]
# ### Issue #6: Correcting invalid dog names (df1)

# %% [markdown]
# #### Define
# 1. Check for the invalid names and switch them for numpy Nan

# %% [markdown]
# #### Code

# %%
sum(df1_clean['name'] == 'A')
#sum(df1_clean['name'] == 'An')
#sum(df1_clean['name'] == 'The')
#sum(df1_clean['name'] == 'Such')
#sum(df1_clean['name'] == 'Just')
#sum(df1_clean['name'] == 'Getting')
# Out:
# 55

# %%
erroneous_names = ['A','An','The', 'Such', 'Just', 'Getting']
for name in erroneous_names:
    df1_clean['name'] = df1_clean['name'].replace(name, np.nan)

# %% [markdown]
# #### Test

# %%
sum(df1_clean['name'] == 'A')
#sum(df1_clean['name'] == 'An')
#sum(df1_clean['name'] == 'The')
#sum(df1_clean['name'] == 'Such')
#sum(df1_clean['name'] == 'Just')
#sum(df1_clean['name'] == 'Getting')
# Out:
# 0

# %% [markdown]
# ### Issue #7: Prediction of dog breeds has inconsistent naming (df2)

# %% [markdown]
# #### Define
# 1. The dog names in the prediction start bwith both upper and lowercase. This needs to be corrected to ensure unifromity

# %% [markdown]
# #### Code

# %%
predictions = df2_clean[["p1", "p2", "p3"]]
predictions.head(15)
# Out:
#                         p1                  p2                           p3
# 0   Welsh_springer_spaniel              collie            Shetland_sheepdog
# 1                  redbone  miniature_pinscher          Rhodesian_ridgeback
# 2          German_shepherd            malinois                   bloodhound
# 3      Rhodesian_ridgeback             redbone           miniature_pinscher
# 4       miniature_pinscher          Rottweiler                     Doberman
# 5     Bernese_mountain_dog    English_springer   Greater_Swiss_Mountain_dog
# 6               box_turtle          mud_turtle                     terrapin
# 7                     chow     Tibetan_mastiff                     fur_coat
# 8            shopping_cart     shopping_basket             golden_retriever
# 9         miniature_poodle            komondor  soft-coated_wheaten_terrier
# 10        golden_retriever     Tibetan_mastiff           Labrador_retriever
# ...

# %%
df2_clean['p1'] = [name.capitalize() for name in df2_clean['p1']]

# %%
df2_clean['p2'] = [name.capitalize() for name in df2_clean['p2']]

# %%
df2_clean['p3'] = [name.capitalize() for name in df2_clean['p3']]

# %% [markdown]
# #### Test

# %%
predictions = df2_clean[["p1", "p2", "p3"]]
predictions.head(15)
# Out:
#                         p1                  p2                           p3
# 0   Welsh_springer_spaniel              Collie            Shetland_sheepdog
# 1                  Redbone  Miniature_pinscher          Rhodesian_ridgeback
# 2          German_shepherd            Malinois                   Bloodhound
# 3      Rhodesian_ridgeback             Redbone           Miniature_pinscher
# 4       Miniature_pinscher          Rottweiler                     Doberman
# 5     Bernese_mountain_dog    English_springer   Greater_swiss_mountain_dog
# 6               Box_turtle          Mud_turtle                     Terrapin
# 7                     Chow     Tibetan_mastiff                     Fur_coat
# 8            Shopping_cart     Shopping_basket             Golden_retriever
# 9         Miniature_poodle            Komondor  Soft-coated_wheaten_terrier
# 10        Golden_retriever     Tibetan_mastiff           Labrador_retriever
# ...

# %% [markdown]
# ### Issue #8: Different columns for dog stages (df1)

# %% [markdown]
# #### Define
# 1. Dog Stages shoulbe be in one column instead of four
# 2. Melt dog stages into one column

# %% [markdown]
# #### Code

# %%
list(df1_clean)
# Out:
# ['tweet_id',
#  'timestamp',
#  'source',
#  'text',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo']

# %%
print(df1_clean.doggo.value_counts())
print(df1_clean.floofer.value_counts())
print(df1_clean.pupper.value_counts())
print(df1_clean.puppo.value_counts())
# Out:
# doggo    83
# Name: doggo, dtype: int64
# floofer    10
# Name: floofer, dtype: int64
# pupper    230
# Name: pupper, dtype: int64
# puppo    24
# Name: puppo, dtype: int64

# %%
df1_clean = pd.melt(df1_clean, id_vars=['tweet_id', 'timestamp', 'source', 'text', 'expanded_urls', 'rating_numerator', 'rating_denominator', 'name'],
                           value_vars = ['doggo', 'floofer', 'pupper', 'puppo'],
                           var_name='stages', value_name='dog_stage')
df1_clean = df1_clean.drop('stages', axis = 1)

# %% [markdown]
# #### Test

# %%
list(df1_clean)
# Out:
# ['tweet_id',
#  'timestamp',
#  'source',
#  'text',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'dog_stage']

# %%
print(df1_clean.dog_stage.value_counts())
# Out:
# pupper     230
# doggo       83
# puppo       24
# floofer     10
# Name: dog_stage, dtype: int64

# %%
df1_clean.head(15)
# Out:
#               tweet_id           timestamp  \
# 0   892420643555336193 2017-08-01 16:23:56
# 1   892177421306343426 2017-08-01 00:17:27
# 2   891815181378084864 2017-07-31 00:18:03
# 3   891689557279858688 2017-07-30 15:58:51
# 4   891327558926688256 2017-07-29 16:00:24
# 5   891087950875897856 2017-07-29 00:08:17
# 6   890971913173991426 2017-07-28 16:27:12
# 7   890729181411237888 2017-07-28 00:22:40
# 8   890609185150312448 2017-07-27 16:25:51
# 9   890240255349198849 2017-07-26 15:59:51
# 10  890006608113172480 2017-07-26 00:31:25
# 11  889880896479866881 2017-07-25 16:11:53
# 12  889665388333682689 2017-07-25 01:55:32
# 13  889638837579907072 2017-07-25 00:10:02
# 14  889531135344209921 2017-07-24 17:02:04
#
#                                                source  \
# 0   <a href="http://twitter.com/download/iphone" r...
# 1   <a href="http://twitter.com/download/iphone" r...
# 2   <a href="http://twitter.com/download/iphone" r...
# ...

# %% [markdown]
# ### Issue #9: 'tweet_id' for all tables is int, should be string (general)

# %% [markdown]
# #### Define
# 1. Since this column is not going t be used to perform any operations, its type should be changed to string instead of int before doing any merging of the datasets

# %% [markdown]
# #### Code

# %%
df1_clean.tweet_id.dtype
#df2_clean.tweet_id.dtype
#df3_clean.tweet_id.dtype
# Out:
# dtype('int64')

# %%
df1_clean = df1_clean.astype({"tweet_id": str})

# %%
df2_clean = df2_clean.astype({"tweet_id": str})

# %%
df3_clean = df3_clean.astype({"tweet_id": str})

# %% [markdown]
# #### Test

# %%
df1_clean.tweet_id.dtype
#df2_clean.tweet_id.dtype
#df3_clean.tweet_id.dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Issue #10: Too many datasets, need to be consolidated (general)

# %% [markdown]
# #### Define
# 1. Merge the first 2 data sets into one data set
# 2. Megrge the last data set with the first two already merged

# %% [markdown]
# #### Code

# %%
twitter_merged = pd.merge(left = df1_clean, right = df2_clean, how = 'left', on = 'tweet_id')

# %%
twitter_merged = pd.merge(left = twitter_merged, right = df3_clean, how='left', on='tweet_id')

# %% [markdown]
# #### Test

# %%
list(twitter_merged)
# Out:
# ['tweet_id',
#  'timestamp',
#  'source',
#  'text',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'dog_stage',
#  'jpg_url',
#  'img_num',
#  'p1',
#  'p1_conf',
#  'p1_dog',
#  'p2',
#  'p2_conf',
#  'p2_dog',
#  'p3',
#  'p3_conf',
#  'p3_dog',
#  'retweet_count',
#  'favorite_count']

# %%
twitter_merged.head(5)
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
# 1  892177421306343426 2017-08-01 00:17:27
# 2  891815181378084864 2017-07-31 00:18:03
# 3  891689557279858688 2017-07-30 15:58:51
# 4  891327558926688256 2017-07-29 16:00:24
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %% [markdown]
# ## Storing Data
# <a id="StoringData"></a>
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
twitter_merged.to_csv('twitter_archive_master.csv' ,index=False, encoding = 'utf-8')

# %% [markdown]
# ## Analyzing and Visualizing Data
# <a id="AnalyzingandVisualizingData"></a>
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %% [markdown]
# #### Analysis done:
#
# 1. Most common dog breeds.
#
# 2. Distribution of dog stages.
#
# 3. Relation between retweets and favourites.
#
# 4. Average rating for the dogs.
#
# 5. Most used tweet source.

# %%
df_master = pd.read_csv('twitter_archive_master.csv')
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8388 entries, 0 to 8387
# Data columns (total 22 columns):
# tweet_id              8388 non-null int64
# timestamp             8388 non-null object
# source                8388 non-null object
# text                  8388 non-null object
# expanded_urls         8376 non-null object
# rating_numerator      8388 non-null int64
# rating_denominator    8388 non-null int64
# name                  5676 non-null object
# dog_stage             347 non-null object
# jpg_url               7884 non-null object
# img_num               7884 non-null float64
# p1                    7884 non-null object
# p1_conf               7884 non-null float64
# p1_dog                7884 non-null object
# p2                    7884 non-null object
# p2_conf               7884 non-null float64
# p2_dog                7884 non-null object
# p3                    7884 non-null object
# p3_conf               7884 non-null float64
# ...

# %%
df_master = df_master.astype({"tweet_id": str})

# %%
df_master.timestamp = pd.to_datetime(df_master.timestamp)

# %%
df_master = df_master.astype({"dog_stage":'category'})

# %%
df_master.dtypes
# Out:
# tweet_id                      object
# timestamp             datetime64[ns]
# source                        object
# text                          object
# expanded_urls                 object
# rating_numerator               int64
# rating_denominator             int64
# name                          object
# dog_stage                   category
# jpg_url                       object
# img_num                      float64
# p1                            object
# p1_conf                      float64
# p1_dog                        object
# p2                            object
# p2_conf                      float64
# p2_dog                        object
# p3                            object
# p3_conf                      float64
# p3_dog                        object
# retweet_count                  int64
# favorite_count                 int64
# dtype: object

# %%
sum(df_master.duplicated())
# Out:
# 5944

# %%
df_master.drop_duplicates(inplace = True)

# %%
sum(df_master.duplicated())
# Out:
# 0

# %%
print(df_master.dog_stage.value_counts())
# Out:
# pupper     230
# doggo       83
# puppo       24
# floofer     10
# Name: dog_stage, dtype: int64

# %%
df_master = df_master.sort_values('dog_stage').drop_duplicates('tweet_id', keep = 'last')

# %%
print(df_master.dog_stage.value_counts())
# Out:
# pupper     230
# doggo       72
# puppo       24
# floofer     10
# Name: dog_stage, dtype: int64

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 7158
# Data columns (total 22 columns):
# tweet_id              2097 non-null object
# timestamp             2097 non-null datetime64[ns]
# source                2097 non-null object
# text                  2097 non-null object
# expanded_urls         2094 non-null object
# rating_numerator      2097 non-null int64
# rating_denominator    2097 non-null int64
# name                  1419 non-null object
# dog_stage             336 non-null category
# jpg_url               1971 non-null object
# img_num               1971 non-null float64
# p1                    1971 non-null object
# p1_conf               1971 non-null float64
# p1_dog                1971 non-null object
# p2                    1971 non-null object
# p2_conf               1971 non-null float64
# p2_dog                1971 non-null object
# p3                    1971 non-null object
# p3_conf               1971 non-null float64
# ...

# %%
df_master.describe()
# Out:
#        rating_numerator  rating_denominator      img_num      p1_conf  \
# count       2097.000000              2097.0  1971.000000  1971.000000
# mean          12.189318                10.0     1.201928     0.594558
# std           40.364996                 0.0     0.559020     0.272126
# min            0.000000                10.0     1.000000     0.044333
# 25%           10.000000                10.0     1.000000     0.363091
# 50%           11.000000                10.0     1.000000     0.587764
# 75%           12.000000                10.0     1.000000     0.847827
# max         1776.000000                10.0     4.000000     1.000000
#
#             p2_conf       p3_conf  retweet_count  favorite_count
# count  1.971000e+03  1.971000e+03    2097.000000     2097.000000
# mean   1.345850e-01  6.016556e-02    2841.667620     8980.902241
# std    1.010527e-01  5.094156e-02    4709.238203    12199.636684
# min    1.011300e-08  1.740170e-10      16.000000       81.000000
# ...

# %%
dict = {'p1': 'Prediction1(p1)',
        'p2': 'Prediction2(p2)',
        'p3': 'Prediction3(p3)',}

df_master.rename(columns = dict, inplace = True)

# %%
list(df_master)
# Out:
# ['tweet_id',
#  'timestamp',
#  'source',
#  'text',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'dog_stage',
#  'jpg_url',
#  'img_num',
#  'Prediction1(p1)',
#  'p1_conf',
#  'p1_dog',
#  'Prediction2(p2)',
#  'p2_conf',
#  'p2_dog',
#  'Prediction3(p3)',
#  'p3_conf',
#  'p3_dog',
#  'retweet_count',
#  'favorite_count']

# %%
df_master.rating_numerator.describe()
# Out:
# count    2097.000000
# mean       12.189318
# std        40.364996
# min         0.000000
# 25%        10.000000
# 50%        11.000000
# 75%        12.000000
# max      1776.000000
# Name: rating_numerator, dtype: float64

# %%
df_master['source'] = df_master['source'].replace('<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'iPhone')
df_master['source'] = df_master['source'].replace('<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'Twitter Web Client')
df_master['source'] = df_master['source'].replace('<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'Tweet Deck')
df_master['source'] = df_master['source'].replace('<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>', 'Vine - Make a Scene')

# %%
tweet_sources = df_master.source.value_counts()
tweet_sources
# Out:
# iPhone                 1964
# Vine - Make a Scene      91
# Twitter Web Client       31
# Tweet Deck               11
# Name: source, dtype: int64

# %% [markdown]
# ### Visualization

# %% [markdown]
# ##### 1. Most Common Dog Breeds

# %%
common_breeds = df_master['Prediction1(p1)'].value_counts().head(10)
common_breeds
# Out:
# Golden_retriever      137
# Labrador_retriever     94
# Pembroke               88
# Chihuahua              78
# Pug                    54
# Chow                   41
# Samoyed                40
# Pomeranian             38
# Toy_poodle             37
# Malamute               29
# Name: Prediction1(p1), dtype: int64

# %%
common_breeds2 = df_master['Prediction2(p2)'].value_counts().head(10)
common_breeds2
# Out:
# Labrador_retriever          95
# Golden_retriever            82
# Cardigan                    73
# Chihuahua                   43
# Chesapeake_bay_retriever    40
# French_bulldog              39
# Pomeranian                  38
# Toy_poodle                  36
# Siberian_husky              33
# Cocker_spaniel              32
# Name: Prediction2(p2), dtype: int64

# %%
least_common_breeds = df_master['Prediction1(p1)'].value_counts().tail(25)
least_common_breeds
# Out:
# Fountain          1
# Skunk             1
# Dough             1
# Maillot           1
# Hand_blower       1
# Scorpion          1
# Restaurant        1
# Sliding_door      1
# Madagascar_cat    1
# Limousine         1
# Water_bottle      1
# Mailbox           1
# Bookcase          1
# Bee_eater         1
# Washer            1
# Platypus          1
# African_grey      1
# Beaver            1
# Tiger_shark       1
# Bonnet            1
# Otter             1
# Handkerchief      1
# Pedestal          1
# Coral_reef        1
# Suit              1
# Name: Prediction1(p1), dtype: int64

# %%
common_breeds.plot(kind = 'barh')
plt.title('Most Common Dog Breeds')
plt.xlabel('Count')
plt.ylabel('Dog Breed')
# Out:
# Text(0,0.5,'Dog Breed')

# %% [markdown]
# ##### 2. Distribution of Dog Stages

# %%
dog_stages = common_breeds = df_master['dog_stage'].value_counts()
dog_stages
# Out:
# pupper     230
# doggo       72
# puppo       24
# floofer     10
# Name: dog_stage, dtype: int64

# %%
y = dog_stages
mylabels =['pupper', 'doggo', 'puppo','floofer']    
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, autopct='%1.1f%%', shadow = True)
plt.legend(title = "Dog Stages:")
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 3. Relation between Retweets and Favourites

# %%
sns.regplot(x = "retweet_count", y = "favorite_count", data= df_master)
plt.xlabel('Retweets')
plt.ylabel('Favourites')
plt.title('Retweets and Favorites')
# Out:
# Text(0.5,1,'Retweets and Favorites')

# %% [markdown]
# ##### 4. Sources of tweets

# %%
tweet_sources.plot(kind = 'bar')
plt.title('Tweet Sources')
plt.xlabel('Count')
plt.ylabel('Tweet Sources')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)

# %% [markdown]
# ### Insights:
# 1. The mean rating score for the 2097 dogs in this dataframe was 12 (out of 10)
#
# 2. The most common source for the tweets was iPhone
#
# 3. The most popular dog breed according to the first prediction was the Golden Retreiver
#
# 4. Retweets and Favourites have a positive correlation, i.e. the more retweets a tweet has, the more favourites it has as well
#
# 5. The most common dog stage was 'pupper' with 66.3% of the dogs (which had been put in a stage category) being in that stage, and the lowest, 'floofer', with only 2.9%.
